# %% [markdown]
# <a href="https://colab.research.google.com/github/Wmartevi/senac2019/blob/master/visaocomputacional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/My\ Drive/People_Detection/dadosImagem/Treinamento/positivos

# %%
# !ln -s drive/My\ Drive/People_Detection/dadosImagem/ /content/Aula

# %%
import cv2

# %%
# !ls Aula/Treinamento/positivos/
# Out:
#  crop_000010.png       crop001516.png	     person_143.png
#  crop_000011.png       crop001517.png	     person_156.png
#  crop_000606.png       crop001518.png	     person_160.png
#  crop_000607.png       crop001519.png	     person_162.png
#  crop_000608.png       crop001523.png	     person_166.png
#  crop001001.png        crop001524.png	     person_167.png
#  crop001003.png        crop001525.png	     person_168.png
#  crop001004.png        crop001527.png	     person_171.png
#  crop001005.png        crop001528.png	     person_172.png
#  crop001007.png        crop001529.png	     person_173.png
#  crop001010.png        crop001530.png	     person_175.png
#  crop001011.png        crop001532.png	     person_176.png
#  crop001013.png        crop001534.png	     person_177.png
#  crop001014.png        crop001537.png	     person_181.png
#  crop001017.png        crop001541.png	     person_195.png
#  crop001018.png        crop001542.png	     person_196.png
# ...

# %%
img_caminho = 'Aula/Treinamento/positivos/crop_000010.png'
img_teste = cv2.imread(img_caminho)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img_teste)
# Out:
# <PIL.Image.Image image mode=RGB size=594x720 at 0x7FCEEFA44EB8>
